# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread("rabbit.png",cv2.IMREAD_GRAYSCALE)
image_array = np.array(img)
print(image_array)
def sharpen():
  return np.array([[1,1,1],[1,1,1],[1,1,1]])
def filtering(image, kernel):
    m, n = kernel.shape
    if (m == n):
        y, x = image.shape
        y = y - m + 1 # shape of image - shape of kernel + 1
        x = x - m + 1
        new_image = np.zeros((y,x))
        for i in range(y):
            for j in range(x):
                new_image[i][j] = np.sum(image[i:i+m, j:j+m]*kernel)
    return new_image
# Display the original and sharpened images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image_array,cmap='gray')
plt.title("Original Grayscale Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(filtering(image_array, sharpen()),cmap='gray')
plt.title("Blurred Image")
plt.axis("off")
plt.show()
# Out:
# [[255 255 175 ... 127 127 127]
#  [255 165 123 ... 127 127 127]
#  [174 120 123 ... 125 125 125]
#  ...
#  [132 132 132 ... 125 114 120]
#  [132 133 132 ... 117 119 119]
#  [133 135 134 ... 123 122 109]]
